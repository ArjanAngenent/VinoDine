# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
csv_file_path = '/Users/florianhaindl/code/ArjanAngenent/VinoDine/raw_data/XWines_Full_100K_wines.csv'
df_new = pd.read_csv(csv_file_path)
df_new.head()
# Out:
#    WineID                         WineName       Type  \
# 0  100001               Espumante Moscatel  Sparkling
# 1  100002                       Ancellotta        Red
# 2  100003               Cabernet Sauvignon        Red
# 3  100004                   Virtus Moscato      White
# 4  100005  Maison de Ville Cabernet-Merlot        Red
#
#                        Elaborate                            Grapes  \
# 0                  Varietal/100%                ['Muscat/Moscato']
# 1                  Varietal/100%                    ['Ancellotta']
# 2                  Varietal/100%            ['Cabernet Sauvignon']
# 3                  Varietal/100%                ['Muscat/Moscato']
# 4  Assemblage/Bordeaux Red Blend  ['Cabernet Sauvignon', 'Merlot']
#
#                                            Harmonize   ABV           Body  \
# 0                 ['Pork', 'Rich Fish', 'Shellfish']   7.5  Medium-bodied
# 1  ['Beef', 'Barbecue', 'Codfish', 'Pasta', 'Pizz...  12.0  Medium-bodied
# ...

# %%
df_new['Harmonize'] = df_new[['Harmonize']].apply(lambda string: string.str.strip("[").str.rstrip("]").str.replace("'","").str.replace(" ",""))
df_new['Harmonize'] = df_new['Harmonize'].str.split(",")
df_new['Grapes'] = df_new[['Grapes']].apply(lambda string: string.str.strip("[").str.rstrip("]").str.replace("'","").str.replace(" ",""))
df_new['Grapes'] = df_new['Grapes'].str.split(",")
df_new.head()
# Out:
#    WineID                         WineName       Type  \
# 0  100001               Espumante Moscatel  Sparkling
# 1  100002                       Ancellotta        Red
# 2  100003               Cabernet Sauvignon        Red
# 3  100004                   Virtus Moscato      White
# 4  100005  Maison de Ville Cabernet-Merlot        Red
#
#                        Elaborate                       Grapes  \
# 0                  Varietal/100%             [Muscat/Moscato]
# 1                  Varietal/100%                 [Ancellotta]
# 2                  Varietal/100%          [CabernetSauvignon]
# 3                  Varietal/100%             [Muscat/Moscato]
# 4  Assemblage/Bordeaux Red Blend  [CabernetSauvignon, Merlot]
#
#                                          Harmonize   ABV           Body  \
# 0                      [Pork, RichFish, Shellfish]   7.5  Medium-bodied
# 1  [Beef, Barbecue, Codfish, Pasta, Pizza, Cheese]  12.0  Medium-bodied
# ...

# %%
df_exploded = df_new.explode('Harmonize')

# %%
df_exploded
# Out:
#         WineID            WineName       Type         Elaborate  \
# 0       100001  Espumante Moscatel  Sparkling     Varietal/100%
# 0       100001  Espumante Moscatel  Sparkling     Varietal/100%
# 0       100001  Espumante Moscatel  Sparkling     Varietal/100%
# 1       100002          Ancellotta        Red     Varietal/100%
# 1       100002          Ancellotta        Red     Varietal/100%
# ...        ...                 ...        ...               ...
# 100645  200795           Rotleiten        Red  Assemblage/Blend
# 100645  200795           Rotleiten        Red  Assemblage/Blend
# 100645  200795           Rotleiten        Red  Assemblage/Blend
# 100645  200795           Rotleiten        Red  Assemblage/Blend
# 100645  200795           Rotleiten        Red  Assemblage/Blend
#
#                                            Grapes        Harmonize   ABV  \
# 0                                [Muscat/Moscato]             Pork   7.5
# ...

# %%
# Zuerst zähle die Häufigkeit jedes Werts in der Spalte "Harmonize"
harmonize_counts_new = df_exploded['Harmonize'].value_counts()

# Wähle die Einträge aus, die weniger als 500 Mal vorkommen
selected_values_new = harmonize_counts_new[harmonize_counts_new >= 100].index

# Filtere den DataFrame, um nur die Zeilen zu behalten, deren "Harmonize"-Eintrag in selected_values enthalten ist
df_filtered_new = df_exploded[df_exploded['Harmonize'].isin(selected_values_new)]

# %%
df_filtered_new['Harmonize'].value_counts()
# Out:
# Harmonize
# Poultry            58315
# Beef               57774
# Lamb               38725
# GameMeat           36436
# Pork               25406
# Shellfish          25005
# Veal               24707
# Pasta              22486
# RichFish           18680
# Vegetarian         18278
# CuredMeat          16631
# SpicyFood          13509
# SoftCheese         10179
# MaturatedCheese     9912
# HardCheese          9730
# LeanFish            9633
# Appetizer           9144
# Snack               7750
# SweetDessert        2936
# GoatCheese          2619
# Mushrooms           1832
# BlueCheese          1175
# FruitDessert         947
# Dessert              186
# Fruit                170
# Fish                 152
# Barbecue             141
# Seafood              126
# Cheese               118
# Name: count, dtype: int64

# %%
df_filtered_new.head()
# Out:
#    WineID            WineName       Type      Elaborate            Grapes  \
# 0  100001  Espumante Moscatel  Sparkling  Varietal/100%  [Muscat/Moscato]
# 0  100001  Espumante Moscatel  Sparkling  Varietal/100%  [Muscat/Moscato]
# 0  100001  Espumante Moscatel  Sparkling  Varietal/100%  [Muscat/Moscato]
# 1  100002          Ancellotta        Red  Varietal/100%      [Ancellotta]
# 1  100002          Ancellotta        Red  Varietal/100%      [Ancellotta]
#
#    Harmonize   ABV           Body Acidity Code Country  RegionID  \
# 0       Pork   7.5  Medium-bodied    High   BR  Brazil      1001
# 0   RichFish   7.5  Medium-bodied    High   BR  Brazil      1001
# 0  Shellfish   7.5  Medium-bodied    High   BR  Brazil      1001
# 1       Beef  12.0  Medium-bodied  Medium   BR  Brazil      1001
# 1      Pasta  12.0  Medium-bodied  Medium   BR  Brazil      1001
#
#      RegionName  WineryID   WineryName                           Website  \
# ...

# %%
#df_filtered_new_exploded = df_filtered_new.explode('Grapes')

# %%
#df_filtered_new_exploded

# %%
#count 
#grape_counts_new = df_filtered_new_exploded['Grapes'].value_counts()

#selected_values_grapes_new = grape_counts_new[grape_counts_new >= 2000].index

# filtering the data frame
#df_grape_filtered_new = df_filtered_new_exploded[df_filtered_new_exploded['Grapes'].isin(selected_values_grapes_new)]

# %%
#df_grape_filtered_new

# %%
#df_grape_filtered_new['Grapes'].value_counts()

# %%
cleaned_data = df_filtered_new

# %%
cleaned_data.head()
# Out:
#    WineID            WineName       Type      Elaborate            Grapes  \
# 0  100001  Espumante Moscatel  Sparkling  Varietal/100%  [Muscat/Moscato]
# 0  100001  Espumante Moscatel  Sparkling  Varietal/100%  [Muscat/Moscato]
# 0  100001  Espumante Moscatel  Sparkling  Varietal/100%  [Muscat/Moscato]
# 1  100002          Ancellotta        Red  Varietal/100%      [Ancellotta]
# 1  100002          Ancellotta        Red  Varietal/100%      [Ancellotta]
#
#    Harmonize   ABV           Body Acidity Code Country  RegionID  \
# 0       Pork   7.5  Medium-bodied    High   BR  Brazil      1001
# 0   RichFish   7.5  Medium-bodied    High   BR  Brazil      1001
# 0  Shellfish   7.5  Medium-bodied    High   BR  Brazil      1001
# 1       Beef  12.0  Medium-bodied  Medium   BR  Brazil      1001
# 1      Pasta  12.0  Medium-bodied  Medium   BR  Brazil      1001
#
#      RegionName  WineryID   WineryName                           Website  \
# ...

# %%
cleaned_data = cleaned_data.drop(['Vintages', 'Website','Grapes'], axis=1)

# %%
cleaned_data.head()
# Out:
#    WineID            WineName       Type      Elaborate  Harmonize   ABV  \
# 0  100001  Espumante Moscatel  Sparkling  Varietal/100%       Pork   7.5
# 0  100001  Espumante Moscatel  Sparkling  Varietal/100%   RichFish   7.5
# 0  100001  Espumante Moscatel  Sparkling  Varietal/100%  Shellfish   7.5
# 1  100002          Ancellotta        Red  Varietal/100%       Beef  12.0
# 1  100002          Ancellotta        Red  Varietal/100%      Pasta  12.0
#
#             Body Acidity Code Country  RegionID    RegionName  WineryID  \
# 0  Medium-bodied    High   BR  Brazil      1001  Serra Gaúcha     10001
# 0  Medium-bodied    High   BR  Brazil      1001  Serra Gaúcha     10001
# 0  Medium-bodied    High   BR  Brazil      1001  Serra Gaúcha     10001
# 1  Medium-bodied  Medium   BR  Brazil      1001  Serra Gaúcha     10001
# 1  Medium-bodied  Medium   BR  Brazil      1001  Serra Gaúcha     10001
#
#     WineryName
# 0  Casa Perini
# 0  Casa Perini
# 0  Casa Perini
# 1  Casa Perini
# ...

# %%
cleaned_data.shape
# Out:
# (421809, 14)

# %%
wine_df = cleaned_data

# %%
wine_df['Harmonize'].value_counts()
# Out:
# Harmonize
# Poultry            58315
# Beef               57774
# Lamb               38725
# GameMeat           36436
# Pork               25406
# Shellfish          25005
# Veal               24707
# Pasta              22486
# RichFish           18680
# Vegetarian         18278
# CuredMeat          16631
# SpicyFood          13509
# SoftCheese         10179
# MaturatedCheese     9912
# HardCheese          9730
# LeanFish            9633
# Appetizer           9144
# Snack               7750
# SweetDessert        2936
# GoatCheese          2619
# Mushrooms           1832
# BlueCheese          1175
# FruitDessert         947
# Name: count, dtype: int64

# %%
def combine_harmonize_classes(harmonize):
    if harmonize in ['Beef', 'Lamb', 'Veal', 'GameMeat', 'Pork']:
        return 'Meat'
    elif harmonize in ['Poultry', 'Duck', 'Chicken', 'Turkey']:
        return 'Poultry'
    elif harmonize in ['Shellfish']:
        return 'Shellfish'
    elif harmonize in ['Pasta']:
        return 'Pasta'
    elif harmonize in ['RichFish']:
        return 'RichFish'
    elif harmonize in ['Vegetarian','Mushrooms']:
        return 'Vegetarian'
    elif harmonize in ['Cheese', 'SoftCheese', 'MaturatedCheese', 'HardCheese', 'GoatCheese', 'BlueCheese']:
        return 'Cheese'
    elif harmonize in ['CuredMeat']:
        return 'CuredMeat'
    elif harmonize in ['SpicyFood']:
        return 'SpicyFood'
    elif harmonize in ['Appetizer', 'Snack']:
        return 'Appetizer and Snacks'
    elif harmonize in ['SweetDessert', 'FruitDessert', 'Dessert']:
        return 'Desserts'
    else:
        return harmonize

# Neue Spalte mit zusammengefassten Harmonize-Klassen erstellen
wine_df['Harmonize_Combined'] = wine_df['Harmonize'].apply(combine_harmonize_classes)

# Überprüfen der aktualisierten Klassenverteilung
print(wine_df['Harmonize_Combined'].value_counts())
# Out:
# Harmonize_Combined
# Meat                    183048
# Poultry                  58315
# Cheese                   33615
# Shellfish                25005
# Pasta                    22486
# Vegetarian               20110
# RichFish                 18680
# Appetizer and Snacks     16894
# CuredMeat                16631
# SpicyFood                13509
# LeanFish                  9633
# Desserts                  3883
# Name: count, dtype: int64

# %% [markdown]
# # 6. Preprosseing

# %%
y = wine_df['Harmonize_Combined']
X = wine_df[['Type', 'ABV', 'Body', 'Acidity']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# features to select: Type, Elaborate, Grapes, ABV, Body, Acidity
# target: harmonize
#y = wine_df['Harmonize']
#X = wine_df[['Type', 'ABV', 'Body', 'Acidity']]
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Create OneHotEncoder
ohe = OneHotEncoder(sparse_output=False)
# Create Ordinal Enoder for Acidity with 3 categories ['High', 'Medium', 'Low']
# ordinal_encoder = OrdinalEncoder(categories=[['High', 'Medium', 'Low']])
# Create StandardScaler for ABV(numerical feeature)
min_max_scaler = MinMaxScaler()

# fit_transform encoders and scalers to X_train
X_train[ohe.get_feature_names_out()] = ohe.fit_transform(X_train[['Type','Body','Acidity']])
# X_train['encoded_acidicity'] = ordinal_encoder.fit_transform(X_train[['Acidity']])
X_train['ABV'] = min_max_scaler.fit_transform(X_train[['ABV']])
X_train.drop(columns=['Type','Body', 'Acidity'], inplace=True)
# transform X_test with encoders and scalers
X_test[ohe.get_feature_names_out()] = ohe.transform(X_test[['Type','Body','Acidity']])
# X_test['encoded_acidicity'] = ordinal_encoder.transform(X_test[['Acidity']])
X_test['ABV'] = min_max_scaler.transform(X_test[['ABV']])
X_test.drop(columns=['Type', 'Body', 'Acidity'], inplace=True)

# %%
X_train.head()
# Out:
#             ABV  Type_Dessert  Type_Dessert/Port  Type_Red  Type_Rosé  \
# 68402  0.476838           0.0                0.0       1.0        0.0
# 37598  0.546758           0.0                0.0       1.0        0.0
# 55355  1.595558           0.0                0.0       1.0        0.0
# 86976 -1.900443           0.0                0.0       0.0        1.0
# 35297 -0.152442           0.0                0.0       1.0        0.0
#
#        Type_Sparkling  Type_White  Body_Full-bodied  Body_Light-bodied  \
# 68402             0.0         0.0               1.0                0.0
# 37598             0.0         0.0               0.0                0.0
# 55355             0.0         0.0               0.0                0.0
# 86976             0.0         0.0               0.0                0.0
# 35297             0.0         0.0               0.0                1.0
#
#        Body_Medium-bodied  Body_Very full-bodied  Body_Very light-bodied  \
# ...

# %%
y_train.head()
# Out:
# 68402    Cheese
# 37598      Meat
# 55355      Meat
# 86976      Meat
# 35297      Meat
# Name: Harmonize_Combined, dtype: object

# %% [markdown]
# # 7. Modeling Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)


rf_classifier.fit(X_train, y_train)


y_pred = rf_classifier.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of the Random Forest Classifiers:", accuracy)
# Out:
# Accuracy of the Random Forest Classifiers: 0.45922729823064096

# %% [markdown]
# # 8. Scaling numerical_features

# %% [markdown]
# # 10. Model Linear Regerssion

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.multiclass import OneVsRestClassifier

# %%
model = LogisticRegression(max_iter=1000)
OVR = OneVsRestClassifier(model)

# %%
OVR.fit(X_train, y_train)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression(max_iter=1000))

# %%
y_pred = OVR.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
print('Accuracy of the Model is:', accuracy)
# Out:
# Accuracy of the Model is: 0.45151450495088624

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
# /Users/florianhaindl/.pyenv/versions/3.10.6/envs/VinoDine/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/florianhaindl/.pyenv/versions/3.10.6/envs/VinoDine/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                       precision    recall  f1-score   support
#
# Appetizer and Snacks       0.40      0.18      0.25      5086
#               Cheese       0.16      0.13      0.14     10109
#            CuredMeat       0.02      0.00      0.00      5010
# ...
